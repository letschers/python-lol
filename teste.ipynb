# %%
client = pymongo.MongoClient('localhost', 27017)

db = client['db-teste']
collection = db['collection-teste']

post = {"author": "rerere",
        "text": "Firstrerecument on my db!",
        "tags": ["db", "mrererengodb", "felicidade"],
        "date": datetime.datetime.utcnow()
        }


posts = db.posts
post_id = posts.insert_one(post).inserted_id
post_id

db.list_collection_names()

posts.find_one({"author" : "rerere"})
# Out:
# {'_id': ObjectId('5c63355d34d23a266dabbf14'),
#  'author': 'rerere',
#  'text': 'Firstrerecument on my db!',
#  'tags': ['db', 'mrererengodb', 'felicidade'],
#  'date': datetime.datetime(2019, 2, 12, 21, 6, 37, 118000)}

# %%
API_KEY = 'RGAPI-aef8946b-0a48-42ce-8aca-1ea9bed2b95a'

playerName = input()

response = requests.get('https://br1.api.riotgames.com/lol/summoner/v4/summoners/by-name/' + playerName + '?api_key=' + API_KEY)
json = response.json()
# Out:
# chaoshimself

# %%
print(json['accountId'])
# Out:
# 2iOOSqQD5fvpgiS7I_DpV_LjXNuYcBhnVY5Iy3ek92zD

# %%
match_url = 'https://br1.api.riotgames.com/lol/match/v4/matches/1574277021?api_key=RGAPI-aef8946b-0a48-42ce-8aca-1ea9bed2b95a'

r = requests.get(match_url)

# %%
json = r.json()

# %%
for i in json.items():
    print (i)
# Out:
# ('gameId', 1574277021)
# ('platformId', 'BR1')
# ('gameCreation', 1548840557752)
# ('gameDuration', 1629)
# ('queueId', 420)
# ('mapId', 11)
# ('seasonId', 13)
# ('gameVersion', '9.2.261.2172')
# ('gameMode', 'CLASSIC')
# ('gameType', 'MATCHED_GAME')
# ...

# %%
cols = {'gameId': json['gameId'],
        'part_1_summ': json['participantIdentities'][0]['player']['summonerName'],
        'part_2_summ': json['participantIdentities'][1]['player']['summonerName'],
        'part_1_summ': 
json['participantIdentities'][2]['player']['summonerName']
json['participantIdentities'][3]['player']['summonerName']
json['participantIdentities'][4]['player']['summonerName']
json['participantIdentities'][5]['player']['summonerName']
json['participantIdentities'][6]['player']['summonerName']
json['participantIdentities'][7]['player']['summonerName']
json['participantIdentities'][8]['player']['summonerName']
json['participantIdentities'][9]['player']['summonerName']}
# Out:
# 1574277021

# %%
l = []
for i in range(10):
    l.append("json['participantIdentities'][{}]['player']['summonerName']".format(i))

# %%
for i in l:
    print(i)
# Out:
# json['participantIdentities'][0]['player']['summonerName']
# json['participantIdentities'][1]['player']['summonerName']
# json['participantIdentities'][2]['player']['summonerName']
# json['participantIdentities'][3]['player']['summonerName']
# json['participantIdentities'][4]['player']['summonerName']
# json['participantIdentities'][5]['player']['summonerName']
# json['participantIdentities'][6]['player']['summonerName']
# json['participantIdentities'][7]['player']['summonerName']
# json['participantIdentities'][8]['player']['summonerName']
# json['participantIdentities'][9]['player']['summonerName']

# %%
json['participantIdentities'][0]['player']['summonerName']
# Out:
# 'chaos himself'

# %%
json
# Out:
# {'gameId': 1574277021,
#  'platformId': 'BR1',
#  'gameCreation': 1548840557752,
#  'gameDuration': 1629,
#  'queueId': 420,
#  'mapId': 11,
#  'seasonId': 13,
#  'gameVersion': '9.2.261.2172',
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'teams': [{'teamId': 100,
#    'win': 'Fail',
#    'firstBlood': False,
#    'firstTower': False,
#    'firstInhibitor': False,
#    'firstBaron': False,
#    'firstDragon': True,
#    'firstRiftHerald': False,
#    'towerKills': 0,
#    'inhibitorKills': 0,
#    'baronKills': 0,
#    'dragonKills': 1,
#    'vilemawKills': 0,
#    'riftHeraldKills': 0,
#    'dominionVictoryScore': 0,
#    'bans': [{'championId': 145, 'pickTurn': 1},
#     {'championId': 92, 'pickTurn': 2},
#     {'championId': 142, 'pickTurn': 3},
#     {'championId': 412, 'pickTurn': 4},
#     {'championId': 30, 'pickTurn': 5}]},
#   {'teamId': 200,
#    'win': 'Win',
#    'firstBlood': True,
#    'firstTower': True,
#    'firstInhibitor': True,
# ...
